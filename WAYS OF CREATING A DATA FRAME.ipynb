# %%
import pandas as pd
df=pd.read_csv('C://Users/mishr/Desktop/excel files/nyc_temperature.csv',skiprows=1,header=None,names=['date','tmax','tmin','tavg','windspeed','precipiitation','snowfall','a','B','C'])
df
# Out:
#          date  tmax  tmin  tavg  windspeed  precipiitation  snowfall     a  B  \
# 0      1/1/19    60    40  50.0       13.9              15         0  0.08  0
# 1      2/1/19    41    35  38.0        2.1              27         0     0  0
# 2      3/1/19    45    39  42.0        6.3              23         0     T  0
# 3      4/1/19    47    37  42.0        6.5              23         0     0  0
# 4      5/1/19    47    42  44.5        9.1              20         0  0.45  0
# ..        ...   ...   ...   ...        ...             ...       ...   ... ..
# 360  27/12/19    54    42  48.0       10.8              17         0     T  0
# 361  28/12/19    50    44  47.0       10.0              18         0     0  0
# 362  29/12/19    44    38  41.0        4.3              24         0  0.29  0
# 363  30/12/19    43    38  40.5        4.0              24         0  0.49  0
# 364  31/12/19    46    38  42.0        5.7              23         0  0.01  0
#
#      C
# 0    0
# 1    0
# ...

# %%
new=df.set_index('date')

# %%
new
# Out:
#           tmax  tmin  tavg  departure  HDD  CDD precipitation new_snow  \
# date
# 1/1/19      60    40  50.0       13.9   15    0          0.08        0
# 2/1/19      41    35  38.0        2.1   27    0             0        0
# 3/1/19      45    39  42.0        6.3   23    0             T        0
# 4/1/19      47    37  42.0        6.5   23    0             0        0
# 5/1/19      47    42  44.5        9.1   20    0          0.45        0
# ...        ...   ...   ...        ...  ...  ...           ...      ...
# 27/12/19    54    42  48.0       10.8   17    0             T        0
# 28/12/19    50    44  47.0       10.0   18    0             0        0
# 29/12/19    44    38  41.0        4.3   24    0          0.29        0
# 30/12/19    43    38  40.5        4.0   24    0          0.49        0
# 31/12/19    46    38  42.0        5.7   23    0          0.01        0
#
#          snow_depth
# date
# 1/1/19            0
# 2/1/19            0
# 3/1/19            0
# ...

# %%
new_df=pd.read_excel('C://Users/mishr/Documents/UDAY BHASKAR 1/UDAY BHASKAR WORK SHEET.xlsx')

# %%
new_df
# Out:
#     S.NO DSCN NUMBER             NAME        FATHER'S NAME    CLASS  \
# 0      1    DSCN2930  HARDIK SHIRIVAS      ASHISH SHIRIVAS  NURSERY
# 1      2    DSCN2931       GAURAD DAS  MUKESH DAS MANIPURI  NURSERY
# 2      3    DSCN2932     ADARSH GUPTA       AMARNATH GUPTA  NURSERY
# 3      4    DSCN2933      NAINA VERMA         DHARMA VERMA  NURSERY
# 4      5    DSCN2935        D.MITANSH     D.YOGDISHWAR RAO  NURSERY
# ..   ...         ...              ...                  ...      ...
# 66    67    DSCN0751      SURAJ YADAV         SANJAY YADAV    8TH B
# 67    68    DSCN0750    RITANSHU SAHU         NARAYAN SAHU    8TH B
# 68    69    DSCN0753       VISHVANATH         ISHWAR YADAV    8TH B
# 69    70    DSCN0820          SHUBHAM            RAM JANAM    3RD
# 70    71        PP01  ANSHIKA MANGORE         SONU MANGORE  NURSERY
#
#           DATE OF BIRTH                                            ADDRESS  \
# 0             17/3/2017           CAMP 2 WARD 25 SANT RAVIDAS NAGAR BHILAI
# ...

# %%
new_df.set_index('S.NO')
# Out:
#      DSCN NUMBER             NAME        FATHER'S NAME    CLASS  \
# S.NO
# 1       DSCN2930  HARDIK SHIRIVAS      ASHISH SHIRIVAS  NURSERY
# 2       DSCN2931       GAURAD DAS  MUKESH DAS MANIPURI  NURSERY
# 3       DSCN2932     ADARSH GUPTA       AMARNATH GUPTA  NURSERY
# 4       DSCN2933      NAINA VERMA         DHARMA VERMA  NURSERY
# 5       DSCN2935        D.MITANSH     D.YOGDISHWAR RAO  NURSERY
# ...          ...              ...                  ...      ...
# 67      DSCN0751      SURAJ YADAV         SANJAY YADAV    8TH B
# 68      DSCN0750    RITANSHU SAHU         NARAYAN SAHU    8TH B
# 69      DSCN0753       VISHVANATH         ISHWAR YADAV    8TH B
# 70      DSCN0820          SHUBHAM            RAM JANAM    3RD
# 71          PP01  ANSHIKA MANGORE         SONU MANGORE  NURSERY
#
#             DATE OF BIRTH                                            ADDRESS  \
# S.NO
# 1               17/3/2017           CAMP 2 WARD 25 SANT RAVIDAS NAGAR BHILAI
# ...

# %%
df.to_excel('uday')
